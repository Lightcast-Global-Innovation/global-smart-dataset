# %% [markdown]
# # Lightcast Global Smart Dataset - Client
#
# This notebook aims to show the use of Lightcast Global Smart Dataset python cliente.
#
# The API allows you to quickly access data from Lightcast's database to obtain content, trends and projections regarding the labour market.
#
# The Global Smart Dataset are available:
# - RESTFul @ https://solutions-api.lightcast.io for each software developer, the data are in realtime
# - Snowflake, to support the creation of marvellous BI dashboard or to access it with STATA, R, SAS (and of course Python) for each data analyst and data scientist. The data are updated monthly
# - Python Client, to support the integration of Lightcast data in your data science code, the data are in realtime
#
# For documentation is open at:
# https://solutions-api.lightcast.io/docs
#
#
# <a href="https://githubtocolab.com/Lightcast-Global-Innovation/global-smart-dataset/blob/main/notebooks/Lightcast_Global_Smart_Dataset_Client.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>

# %% [markdown]
# # Setup
#
# To use the smart dataset API and the lightcast-smart-dataset client you need a Username and a Password. Please contact our sales team @ sales-europe@lightcast.io

# %%
USERNAME = "****"
PSWD = "****"

# %% [markdown]
# To install the client just use pip

# %%
# !pip install lightcast-smart-dataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightcast-smart-dataset
#   Downloading lightcast_smart_dataset-0.1.31-py3-none-any.whl (10 kB)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from lightcast-smart-dataset) (0.6.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from lightcast-smart-dataset) (1.3.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from lightcast-smart-dataset) (2.23.0)
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 3.7 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->lightcast-smart-dataset) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->lightcast-smart-dataset) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->lightcast-smart-dataset) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->lightcast-smart-dataset) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->lightcast-smart-dataset) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->lightcast-smart-dataset) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->lightcast-smart-dataset) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->lightcast-smart-dataset) (2022.6.15)
# Installing collected packages: xlsxwriter, lightcast-smart-dataset
# Successfully installed lightcast-smart-dataset-0.1.31 xlsxwriter-3.0.3

# %%
from lightcast_client.client import LightcastSmartDataset

# %%
client = LightcastSmartDataset(USERNAME, PSWD)

# %% [markdown]
# # Occupation Insight API - UK

# %% [markdown]
# To obtain the list of occupation available you use the taxonomy client

# %%
client.taxonomy().getSocLevel4()[0]
# Out:
# b'{"data":[{"id":"1115","name":"Chief executives and senior officials","description":"This unit group includes those who head large enterprises and organisations. They plan, direct and co-ordinate, with directors and managers, the resources necessary for the various functions and specialist activities of these enterprises and organisations. The chief executives of hospitals will be classified in this unit group. Senior officials in national government direct the operations of government departments. Senior officials in local government participate in the implementation of local government policies and ensure that legal, statutory and other provisions concerning the running of a local authority are observed. Senior officials of special interest organisations ensure that legal, statutory and other regulations concerning the running of trade associations, employers\xe2\x80\x99 associations, learned societies, trades unions, charitable organisations and similar bodies are observed. Chief executives and senior officials also act as representatives of the organisations concerned for the purposes of high level consultation and negotiation."},{"id":"1116","name":"Elected officers and representatives","description":"Elected representatives in national government formulate and ratify legislation and government policy, act as elected representatives in Parliament, European Parliament, Regional Parliaments or Assemblies, and as representatives of the government and its executive. Elected officers in local government act as representatives in the local authority and participate in the formulation, ratification and implementation of local government policies."},{"id":"1121","name":"Production managers and directors in manufacturing","description":"Production managers and directors in manufacturing plan, organise, direct and co-ordinate the activities and resources necessary for production in manufacturing industries including the maintenance of engineering items, equipment and machinery."},{"id":"1122","name":"Production managers and directors in construction","description":"Production managers and directors in construction direct and co-ordinate resources for the construction and maintenance of civil and structural engineering works including houses, flats, factories, roads and runways, bridges, tunnels and railway works, harbour, dock and marine works and water supply, drainage and sewage works."},{"id":"1123","name":"Production managers and directors in mining and energy","description":"Production managers and directors in mining, energy and water supply plan, organise, direct and co-ordinate the activities and resources necessary for the extraction of minerals and other natural deposits and the production, storage and provision of gas, water and electricity supplies."},{"id":"1131","name":"Financial managers and directors","description":"Financial managers and directors plan, organise, direct and co-ordinate financial information and advise on company financial policy."},{"id":"1132","name":"Marketing and sales directors","description":"Marketing and sales directors plan, organise and direct market research and formulate and implement an organisation\xe2\x80\x99s marketing and sales policies."},{"id":"1133","name":"Purchasing managers and directors","description":"Purchasing managers and directors (not retail) plan, organise, direct and co-ordinate the purchasing functions of industrial, commercial, government organisations and public agencies to ensure cost-effectiveness."},{"id":"1134","name":"Advertising and public relations directors","description":"Advertising and public relations directors plan, organise, direct and co-ordinate the advertising, public relations and public information activities of an organisation."},{"id":"1135","name":"Human resource managers and directors","description":"Human resource managers and directors plan, organise and direct the personnel, training and industrial relations policies of organisations, adv ...
# {'description': 'This unit group includes those who head large enterprises and organisations. They plan, direct and co-ordinate, with directors and managers, the resources necessary for the various functions and specialist activities of these enterprises and organisations. The chief executives of hospitals will be classified in this unit group. Senior officials in national government direct the operations of government departments. Senior officials in local government participate in the implementation of local government policies and ensure that legal, statutory and other provisions concerning the running of a local authority are observed. Senior officials of special interest organisations ensure that legal, statutory and other regulations concerning the running of trade associations, employers’ associations, learned societies, trades unions, charitable organisations and similar bodies are observed. Chief executives and senior officials also act as representatives of the organisations concerned for the purposes of high level consultation and negotiation.',
#  'id': '1115',
#  'name': 'Chief executives and senior officials'}

# %% [markdown]
# Let's convert the results in a Pandas DataFrame

# %%
import pandas as pd

soc4_occupation = pd.DataFrame.from_dict(client.taxonomy().getSocLevel4())
# Out:
# b'{"data":[{"id":"1115","name":"Chief executives and senior officials","description":"This unit group includes those who head large enterprises and organisations. They plan, direct and co-ordinate, with directors and managers, the resources necessary for the various functions and specialist activities of these enterprises and organisations. The chief executives of hospitals will be classified in this unit group. Senior officials in national government direct the operations of government departments. Senior officials in local government participate in the implementation of local government policies and ensure that legal, statutory and other provisions concerning the running of a local authority are observed. Senior officials of special interest organisations ensure that legal, statutory and other regulations concerning the running of trade associations, employers\xe2\x80\x99 associations, learned societies, trades unions, charitable organisations and similar bodies are observed. Chief executives and senior officials also act as representatives of the organisations concerned for the purposes of high level consultation and negotiation."},{"id":"1116","name":"Elected officers and representatives","description":"Elected representatives in national government formulate and ratify legislation and government policy, act as elected representatives in Parliament, European Parliament, Regional Parliaments or Assemblies, and as representatives of the government and its executive. Elected officers in local government act as representatives in the local authority and participate in the formulation, ratification and implementation of local government policies."},{"id":"1121","name":"Production managers and directors in manufacturing","description":"Production managers and directors in manufacturing plan, organise, direct and co-ordinate the activities and resources necessary for production in manufacturing industries including the maintenance of engineering items, equipment and machinery."},{"id":"1122","name":"Production managers and directors in construction","description":"Production managers and directors in construction direct and co-ordinate resources for the construction and maintenance of civil and structural engineering works including houses, flats, factories, roads and runways, bridges, tunnels and railway works, harbour, dock and marine works and water supply, drainage and sewage works."},{"id":"1123","name":"Production managers and directors in mining and energy","description":"Production managers and directors in mining, energy and water supply plan, organise, direct and co-ordinate the activities and resources necessary for the extraction of minerals and other natural deposits and the production, storage and provision of gas, water and electricity supplies."},{"id":"1131","name":"Financial managers and directors","description":"Financial managers and directors plan, organise, direct and co-ordinate financial information and advise on company financial policy."},{"id":"1132","name":"Marketing and sales directors","description":"Marketing and sales directors plan, organise and direct market research and formulate and implement an organisation\xe2\x80\x99s marketing and sales policies."},{"id":"1133","name":"Purchasing managers and directors","description":"Purchasing managers and directors (not retail) plan, organise, direct and co-ordinate the purchasing functions of industrial, commercial, government organisations and public agencies to ensure cost-effectiveness."},{"id":"1134","name":"Advertising and public relations directors","description":"Advertising and public relations directors plan, organise, direct and co-ordinate the advertising, public relations and public information activities of an organisation."},{"id":"1135","name":"Human resource managers and directors","description":"Human resource managers and directors plan, organise and direct the personnel, training and industrial relations policies of organisations, adv ...

# %%
soc4_occupation
# Out:
#        id                                               name  \
# 0    1115              Chief executives and senior officials
# 1    1116               Elected officers and representatives
# 2    1121  Production managers and directors in manufactu...
# 3    1122  Production managers and directors in construction
# 4    1123  Production managers and directors in mining an...
# ..    ...                                                ...
# 364  9272                    Kitchen and catering assistants
# 365  9273                             Waiters and waitresses
# 366  9274                                          Bar staff
# 367  9275                  Leisure and theme park attendants
# 368  9279       Other elementary services occupations n.e.c.
#
#                                            description
# 0    This unit group includes those who head large ...
# 1    Elected representatives in national government...
# 2    Production managers and directors in manufactu...
# 3    Production managers and directors in construct...
# 4    Production managers and directors in mining, e...
# ..                                                 ...
# 364  Workers in this unit group assist in the prepa...
# 365  Waiters and waitresses serve food and beverage...
# 366  Bar staff prepare, mix and serve alcoholic and...
# 367  Leisure and theme park attendants monitor the ...
# 368  Workers in this unit group perform a variety o...
#
# [369 rows x 3 columns]

# %%
soc4_occupation[soc4_occupation["name"].str.contains("software")]
# Out:
#       id                                               name  \
# 51  2136  Programmers and software development professio...
#
#                                           description
# 51  Programmers and software development professio...

# %% [markdown]
# Let's check the area avaialble in UK

# %%
client.taxonomy().getUkNuts3()[0]
# Out:
# b'{"data":[{"id":"UKC11","name":"Hartlepool and Stockton-on-Tees"},{"id":"UKC12","name":"South Teesside"},{"id":"UKC13","name":"Darlington"},{"id":"UKC14","name":"Durham CC"},{"id":"UKC21","name":"Northumberland"},{"id":"UKC22","name":"Tyneside"},{"id":"UKC23","name":"Sunderland"},{"id":"UKD11","name":"West Cumbria"},{"id":"UKD12","name":"East Cumbria"},{"id":"UKD33","name":"Manchester"},{"id":"UKD34","name":"Greater Manchester South West"},{"id":"UKD35","name":"Greater Manchester South East"},{"id":"UKD36","name":"Greater Manchester North West"},{"id":"UKD37","name":"Greater Manchester North East"},{"id":"UKD41","name":"Blackburn with Darwen"},{"id":"UKD42","name":"Blackpool"},{"id":"UKD44","name":"Lancaster and Wyre"},{"id":"UKD45","name":"Mid Lancashire"},{"id":"UKD46","name":"East Lancashire"},{"id":"UKD47","name":"Chorley and West Lancashire"},{"id":"UKD61","name":"Warrington"},{"id":"UKD62","name":"Cheshire East"},{"id":"UKD63","name":"Cheshire West and Chester"},{"id":"UKD71","name":"East Merseyside"},{"id":"UKD72","name":"Liverpool"},{"id":"UKD73","name":"Sefton"},{"id":"UKD74","name":"Wirral"},{"id":"UKE11","name":"Kingston upon Hull, City of"},{"id":"UKE12","name":"East Riding of Yorkshire"},{"id":"UKE13","name":"North and North East Lincolnshire"},{"id":"UKE21","name":"York"},{"id":"UKE22","name":"North Yorkshire CC"},{"id":"UKE31","name":"Barnsley, Doncaster and Rotherham"},{"id":"UKE32","name":"Sheffield"},{"id":"UKE41","name":"Bradford"},{"id":"UKE42","name":"Leeds"},{"id":"UKE44","name":"Calderdale and Kirklees"},{"id":"UKE45","name":"Wakefield"},{"id":"UKF11","name":"Derby"},{"id":"UKF12","name":"East Derbyshire"},{"id":"UKF13","name":"South and West Derbyshire"},{"id":"UKF14","name":"Nottingham"},{"id":"UKF15","name":"North Nottinghamshire"},{"id":"UKF16","name":"South Nottinghamshire"},{"id":"UKF21","name":"Leicester"},{"id":"UKF22","name":"Leicestershire CC and Rutland"},{"id":"UKF24","name":"West Northamptonshire"},{"id":"UKF25","name":"North Northamptonshire"},{"id":"UKF30","name":"Lincolnshire"},{"id":"UKG11","name":"Herefordshire, County of"},{"id":"UKG12","name":"Worcestershire"},{"id":"UKG13","name":"Warwickshire"},{"id":"UKG21","name":"Telford and Wrekin"},{"id":"UKG22","name":"Shropshire CC"},{"id":"UKG23","name":"Stoke-on-Trent"},{"id":"UKG24","name":"Staffordshire CC"},{"id":"UKG31","name":"Birmingham"},{"id":"UKG32","name":"Solihull"},{"id":"UKG33","name":"Coventry"},{"id":"UKG36","name":"Dudley"},{"id":"UKG37","name":"Sandwell"},{"id":"UKG38","name":"Walsall"},{"id":"UKG39","name":"Wolverhampton"},{"id":"UKH11","name":"Peterborough"},{"id":"UKH12","name":"Cambridgeshire CC"},{"id":"UKH14","name":"Suffolk"},{"id":"UKH15","name":"Norwich and East Norfolk"},{"id":"UKH16","name":"North and West Norfolk"},{"id":"UKH17","name":"Breckland and South Norfolk"},{"id":"UKH21","name":"Luton"},{"id":"UKH23","name":"Hertfordshire"},{"id":"UKH24","name":"Bedford"},{"id":"UKH25","name":"Central Bedfordshire"},{"id":"UKH31","name":"Southend-on-Sea"},{"id":"UKH32","name":"Thurrock"},{"id":"UKH34","name":"Essex Haven Gateway"},{"id":"UKH35","name":"West Essex"},{"id":"UKH36","name":"Heart of Essex"},{"id":"UKH37","name":"Essex Thames Gateway"},{"id":"UKI31","name":"Camden and City of London"},{"id":"UKI32","name":"Westminster"},{"id":"UKI33","name":"Kensington & Chelsea and Hammersmith & Fulham"},{"id":"UKI34","name":"Wandsworth"},{"id":"UKI41","name":"Hackney and Newham"},{"id":"UKI42","name":"Tower Hamlets"},{"id":"UKI43","name":"Haringey and Islington"},{"id":"UKI44","name":"Lewisham and Southwark"},{"id":"UKI45","name":"Lambeth"},{"id":"UKI51","name":"Bexley and Greenwich"},{"id":"UKI52","name":"Barking & Dagenham and Havering"},{"id":"UKI53","name":"Redbridge and Waltham Forest"},{"id":"UKI54","name":"Enfield"},{"id":"UKI61","name":"Bromley"},{"id":"UKI62","name":"Croydon"},{"id":"UKI63","name":"Merton, Kingston upon Thames and Sutton"},{"id":"UKI71","name":"Barnet"},{"id":"UKI72","name":"Brent"},{"id":"UKI73" ...
# {'id': 'UKC11', 'name': 'Hartlepool and Stockton-on-Tees'}

# %%
nuts3_uk = pd.DataFrame.from_dict(client.taxonomy().getUkNuts3())
# Out:
# b'{"data":[{"id":"UKC11","name":"Hartlepool and Stockton-on-Tees"},{"id":"UKC12","name":"South Teesside"},{"id":"UKC13","name":"Darlington"},{"id":"UKC14","name":"Durham CC"},{"id":"UKC21","name":"Northumberland"},{"id":"UKC22","name":"Tyneside"},{"id":"UKC23","name":"Sunderland"},{"id":"UKD11","name":"West Cumbria"},{"id":"UKD12","name":"East Cumbria"},{"id":"UKD33","name":"Manchester"},{"id":"UKD34","name":"Greater Manchester South West"},{"id":"UKD35","name":"Greater Manchester South East"},{"id":"UKD36","name":"Greater Manchester North West"},{"id":"UKD37","name":"Greater Manchester North East"},{"id":"UKD41","name":"Blackburn with Darwen"},{"id":"UKD42","name":"Blackpool"},{"id":"UKD44","name":"Lancaster and Wyre"},{"id":"UKD45","name":"Mid Lancashire"},{"id":"UKD46","name":"East Lancashire"},{"id":"UKD47","name":"Chorley and West Lancashire"},{"id":"UKD61","name":"Warrington"},{"id":"UKD62","name":"Cheshire East"},{"id":"UKD63","name":"Cheshire West and Chester"},{"id":"UKD71","name":"East Merseyside"},{"id":"UKD72","name":"Liverpool"},{"id":"UKD73","name":"Sefton"},{"id":"UKD74","name":"Wirral"},{"id":"UKE11","name":"Kingston upon Hull, City of"},{"id":"UKE12","name":"East Riding of Yorkshire"},{"id":"UKE13","name":"North and North East Lincolnshire"},{"id":"UKE21","name":"York"},{"id":"UKE22","name":"North Yorkshire CC"},{"id":"UKE31","name":"Barnsley, Doncaster and Rotherham"},{"id":"UKE32","name":"Sheffield"},{"id":"UKE41","name":"Bradford"},{"id":"UKE42","name":"Leeds"},{"id":"UKE44","name":"Calderdale and Kirklees"},{"id":"UKE45","name":"Wakefield"},{"id":"UKF11","name":"Derby"},{"id":"UKF12","name":"East Derbyshire"},{"id":"UKF13","name":"South and West Derbyshire"},{"id":"UKF14","name":"Nottingham"},{"id":"UKF15","name":"North Nottinghamshire"},{"id":"UKF16","name":"South Nottinghamshire"},{"id":"UKF21","name":"Leicester"},{"id":"UKF22","name":"Leicestershire CC and Rutland"},{"id":"UKF24","name":"West Northamptonshire"},{"id":"UKF25","name":"North Northamptonshire"},{"id":"UKF30","name":"Lincolnshire"},{"id":"UKG11","name":"Herefordshire, County of"},{"id":"UKG12","name":"Worcestershire"},{"id":"UKG13","name":"Warwickshire"},{"id":"UKG21","name":"Telford and Wrekin"},{"id":"UKG22","name":"Shropshire CC"},{"id":"UKG23","name":"Stoke-on-Trent"},{"id":"UKG24","name":"Staffordshire CC"},{"id":"UKG31","name":"Birmingham"},{"id":"UKG32","name":"Solihull"},{"id":"UKG33","name":"Coventry"},{"id":"UKG36","name":"Dudley"},{"id":"UKG37","name":"Sandwell"},{"id":"UKG38","name":"Walsall"},{"id":"UKG39","name":"Wolverhampton"},{"id":"UKH11","name":"Peterborough"},{"id":"UKH12","name":"Cambridgeshire CC"},{"id":"UKH14","name":"Suffolk"},{"id":"UKH15","name":"Norwich and East Norfolk"},{"id":"UKH16","name":"North and West Norfolk"},{"id":"UKH17","name":"Breckland and South Norfolk"},{"id":"UKH21","name":"Luton"},{"id":"UKH23","name":"Hertfordshire"},{"id":"UKH24","name":"Bedford"},{"id":"UKH25","name":"Central Bedfordshire"},{"id":"UKH31","name":"Southend-on-Sea"},{"id":"UKH32","name":"Thurrock"},{"id":"UKH34","name":"Essex Haven Gateway"},{"id":"UKH35","name":"West Essex"},{"id":"UKH36","name":"Heart of Essex"},{"id":"UKH37","name":"Essex Thames Gateway"},{"id":"UKI31","name":"Camden and City of London"},{"id":"UKI32","name":"Westminster"},{"id":"UKI33","name":"Kensington & Chelsea and Hammersmith & Fulham"},{"id":"UKI34","name":"Wandsworth"},{"id":"UKI41","name":"Hackney and Newham"},{"id":"UKI42","name":"Tower Hamlets"},{"id":"UKI43","name":"Haringey and Islington"},{"id":"UKI44","name":"Lewisham and Southwark"},{"id":"UKI45","name":"Lambeth"},{"id":"UKI51","name":"Bexley and Greenwich"},{"id":"UKI52","name":"Barking & Dagenham and Havering"},{"id":"UKI53","name":"Redbridge and Waltham Forest"},{"id":"UKI54","name":"Enfield"},{"id":"UKI61","name":"Bromley"},{"id":"UKI62","name":"Croydon"},{"id":"UKI63","name":"Merton, Kingston upon Thames and Sutton"},{"id":"UKI71","name":"Barnet"},{"id":"UKI72","name":"Brent"},{"id":"UKI73" ...

# %%
nuts3_uk
# Out:
#         id                             name
# 0    UKC11  Hartlepool and Stockton-on-Tees
# 1    UKC12                   South Teesside
# 2    UKC13                       Darlington
# 3    UKC14                        Durham CC
# 4    UKC21                   Northumberland
# ..     ...                              ...
# 176  UKN12         Causeway Coast and Glens
# 177  UKN13          Antrim and Newtownabbey
# 178  UKN14          Lisburn and Castlereagh
# 179  UKN15              Mid and East Antrim
# 180  UKN16              Fermanagh and Omagh
#
# [181 rows x 2 columns]

# %%
nuts3_uk[nuts3_uk["name"].str.contains("London")]
# Out:
#        id                       name
# 79  UKI31  Camden and City of London

# %% [markdown]
# Now, it is the time to use the Global Smart Dataset API with the Occupation Insight

# %%
occupation = "Programmers and software development professionals"
area = "Camden and City of London"

# %%
r = client.ukDataset().getSocOccupationInsight(
    occupation=occupation,
    area=area
)
# Out:
# b'{"area":"Camden and City of London","occupation":"Programmers and software development professionals","date":"2022-07-30T17:33:48.406","area_classification":"nuts3_name","occupation_classification":"soc4_name","salary":{"min":20777,"max":247000,"median":80256,"unique_postings":5315},"current_year_active_postings":{"results":[{"month":"2021-06","unique_postings":616},{"month":"2021-07","unique_postings":630},{"month":"2021-08","unique_postings":604},{"month":"2021-09","unique_postings":584},{"month":"2021-10","unique_postings":519},{"month":"2021-11","unique_postings":563},{"month":"2021-12","unique_postings":578},{"month":"2022-01","unique_postings":821},{"month":"2022-02","unique_postings":1067},{"month":"2022-03","unique_postings":1389},{"month":"2022-04","unique_postings":1535},{"month":"2022-05","unique_postings":1835},{"month":"2022-06","unique_postings":1698}],"total_unique_postings":5315},"previous_year_active_postings":{"results":[{"month":"2020-06","unique_postings":751},{"month":"2020-07","unique_postings":767},{"month":"2020-08","unique_postings":757},{"month":"2020-09","unique_postings":773},{"month":"2020-10","unique_postings":927},{"month":"2020-11","unique_postings":805},{"month":"2020-12","unique_postings":891},{"month":"2021-01","unique_postings":815},{"month":"2021-02","unique_postings":769},{"month":"2021-03","unique_postings":763},{"month":"2021-04","unique_postings":713},{"month":"2021-05","unique_postings":635},{"month":"2021-06","unique_postings":616}],"total_unique_postings":4548},"top_10_specialized_skills":{"results":[{"name":"JavaScript (Programming Language)","unique_postings":1758},{"name":"Java (Programming Language)","unique_postings":1525},{"name":"Amazon Web Services","unique_postings":1313},{"name":"Agile Methodology","unique_postings":1284},{"name":"Python (Programming Language)","unique_postings":1094},{"name":"C# (Programming Language)","unique_postings":1078},{"name":"SQL (Programming Language)","unique_postings":1020},{"name":"Software Engineering","unique_postings":980},{"name":"DevOps","unique_postings":955},{"name":"Microsoft Azure","unique_postings":912}],"limit":10,"rank_by":"unique_postings","analyzed_unique_postings":5315},"top_10_common_skills":{"results":[{"name":"Communications","unique_postings":788},{"name":"Management","unique_postings":432},{"name":"Problem Solving","unique_postings":350},{"name":"Innovation","unique_postings":244},{"name":"Leadership","unique_postings":241},{"name":"Mentorship","unique_postings":232},{"name":"Planning","unique_postings":180},{"name":"Operations","unique_postings":169},{"name":"Research","unique_postings":168},{"name":"Troubleshooting (Problem Solving)","unique_postings":167}],"limit":10,"rank_by":"unique_postings","analyzed_unique_postings":5315},"top_10_employers":{"results":[{"name":"Metro Bank","unique_postings":49},{"name":"Digitech Resourcing","unique_postings":40},{"name":"Uk Spring Cleaners Limited","unique_postings":38},{"name":"Thomson Keene Associates","unique_postings":36},{"name":"Tiro Partners","unique_postings":35},{"name":"Noir","unique_postings":30},{"name":"Intelligent Resource","unique_postings":29},{"name":"Deerfoot","unique_postings":26},{"name":"King\'s College London","unique_postings":26},{"name":"83Zero Limited","unique_postings":22}],"limit":10,"rank_by":"unique_postings","analyzed_unique_postings":1229},"top_10_job_titles":{"results":[{"name":"Java Developers","unique_postings":403},{"name":"DevOps Engineers","unique_postings":258},{"name":"Software Engineers","unique_postings":197},{"name":"C# .NET Developers","unique_postings":146},{"name":"Full Stack Developers","unique_postings":137},{"name":"Software Developers","unique_postings":119},{"name":".NET Developers","unique_postings":99},{"name":"Python Developers","unique_postings":99},{"name":"Java Engineers","unique_postings":86},{"name":"Lead Python Developers","unique_postings":74}],"limit":10,"rank_by":"unique_postings","analyzed_unique_postings":5282}}'

# %% [markdown]
# Now we can use the information returned as a dict or a pandas dataframe.

# %%
refresh_date = r.refresh_date
print(f"Data refreshed at {refresh_date}")
# Out:
# Data refreshed at 2022-07-30T17:33:48.406

# %% [markdown]
# Last 12 months of job postings vs previous 12 months of job postings

# %%
current_year_active_postings = r.current_year_active_postings
previous_year_active_postings = r.previous_year_active_postings

ds_current_year_active_postings = pd.DataFrame.from_dict(current_year_active_postings)
ds_previous_year_active_postings = pd.DataFrame.from_dict(previous_year_active_postings)

# %%
ds_time_series = pd.concat([ds_current_year_active_postings, ds_previous_year_active_postings], axis=1)
ds_time_series
# Out:
#       month  unique_postings    month  unique_postings
# 0   2021-06              616  2020-06              751
# 1   2021-07              630  2020-07              767
# 2   2021-08              604  2020-08              757
# 3   2021-09              584  2020-09              773
# 4   2021-10              519  2020-10              927
# 5   2021-11              563  2020-11              805
# 6   2021-12              578  2020-12              891
# 7   2022-01              821  2021-01              815
# 8   2022-02             1067  2021-02              769
# 9   2022-03             1389  2021-03              763
# 10  2022-04             1535  2021-04              713
# 11  2022-05             1835  2021-05              635
# 12  2022-06             1698  2021-06              616

# %% [markdown]
# Now we can access to the salary distribution

# %%
salary_max = r.salary_max
salary_min = r.salary_min
salary_median = r.salary_median

print(f"Salary max {salary_max:,.2f}")
print(f"Salary min {salary_min:,.2f}")
print(f"Salary median {salary_median:,.2f}")
# Out:
# Salary max 247,000.00
# Salary min 20,777.00
# Salary median 80,256.00

# %% [markdown]
# And the skills data represented as common skills and specialized skills

# %%
top_10_common_skills = r.top_10_common_skills
top_10_specialized_skills = r.top_10_specialized_skills


ds_top_10_common_skills = pd.DataFrame.from_dict(top_10_common_skills)
ds_top_10_specialized_skills = pd.DataFrame.from_dict(top_10_specialized_skills)

# %%
ds_top_10_common_skills
# Out:
#                                 name  unique_postings
# 0                     Communications              788
# 1                         Management              432
# 2                    Problem Solving              350
# 3                         Innovation              244
# 4                         Leadership              241
# 5                         Mentorship              232
# 6                           Planning              180
# 7                         Operations              169
# 8                           Research              168
# 9  Troubleshooting (Problem Solving)              167

# %%
ds_top_10_specialized_skills
# Out:
#                                 name  unique_postings
# 0                     Communications              788
# 1                         Management              432
# 2                    Problem Solving              350
# 3                         Innovation              244
# 4                         Leadership              241
# 5                         Mentorship              232
# 6                           Planning              180
# 7                         Operations              169
# 8                           Research              168
# 9  Troubleshooting (Problem Solving)              167

# %% [markdown]
# Finally we can extract the most common job titles (referred to the last year of web job postings):

# %%
top_10_job_titles = r.top_10_job_titles

ds_top_10_job_titles = pd.DataFrame.from_dict(top_10_job_titles)
ds_top_10_job_titles
# Out:
#                      name  unique_postings
# 0         Java Developers              403
# 1        DevOps Engineers              258
# 2      Software Engineers              197
# 3      C# .NET Developers              146
# 4   Full Stack Developers              137
# 5     Software Developers              119
# 6         .NET Developers               99
# 7       Python Developers               99
# 8          Java Engineers               86
# 9  Lead Python Developers               74

# %% [markdown]
# ...and the most mentioned employers (last year of data)

# %%
top_10_employers = r.top_10_employers

ds_top_10_employers = pd.DataFrame.from_dict(top_10_employers)
ds_top_10_employers
# Out:
#                          name  unique_postings
# 0                  Metro Bank               49
# 1         Digitech Resourcing               40
# 2  Uk Spring Cleaners Limited               38
# 3    Thomson Keene Associates               36
# 4               Tiro Partners               35
# 5                        Noir               30
# 6        Intelligent Resource               29
# 7                    Deerfoot               26
# 8       King's College London               26
# 9              83Zero Limited               22

# %% [markdown]
# # Occupation Insight API - Global

# %% [markdown]
# To obtain the list of occupation available you use the taxonomy client (global)

# %%
client.taxonomy().getOccupation()[0]
# Out:
# b'{"data":[{"id":"1","name":"na"},{"id":"10","name":"Business Development / Sales Manager"},{"id":"100","name":"Financial Quantitative Analyst"},{"id":"101","name":"Risk Manager / Analyst"},{"id":"102","name":"Investment Underwriter"},{"id":"103","name":"Fraud Examiner / Analyst"},{"id":"104","name":"Computer Scientist"},{"id":"105","name":"Data Scientist"},{"id":"106","name":"Systems Analyst"},{"id":"107","name":"Cyber / Information Security Engineer / Analyst"},{"id":"108","name":"Software Developer / Engineer"},{"id":"109","name":"Computer Programmer"},{"id":"11","name":"Communications / Public Relations Manager"},{"id":"110","name":"Mobile Applications Developer"},{"id":"111","name":"Computer Systems Engineer / Architect"},{"id":"112","name":"Web Designer"},{"id":"113","name":"Web Developer"},{"id":"114","name":"UI / UX Designer / Developer"},{"id":"115","name":"Database Administrator"},{"id":"116","name":"Network / Systems Administrator"},{"id":"117","name":"Telecommunications Engineering Specialist"},{"id":"118","name":"Computer Support Specialist"},{"id":"119","name":"Network / Systems Support Specialist"},{"id":"12","name":"Fundraising Manager"},{"id":"120","name":"Technology Consultant"},{"id":"121","name":"Software QA Engineer / Tester"},{"id":"122","name":"Network Engineer / Architect"},{"id":"123","name":"Webmaster / Administrator"},{"id":"124","name":"Geographer / GIS Specialist"},{"id":"125","name":"Database Architect"},{"id":"126","name":"Data Warehousing Specialist"},{"id":"127","name":"Project Manager"},{"id":"128","name":"Search Engine Optimization Specialist"},{"id":"129","name":"Video Game Designer"},{"id":"13","name":"Facilities Manager"},{"id":"130","name":"Document Control / Management Specialist"},{"id":"131","name":"Data / Data Mining Analyst"},{"id":"132","name":"Business Intelligence Analyst"},{"id":"133","name":"Business Intelligence Architect / Developer"},{"id":"134","name":"IT Project Manager"},{"id":"135","name":"Actuary"},{"id":"136","name":"Mathematician"},{"id":"137","name":"Operations Analyst"},{"id":"138","name":"Statistician"},{"id":"139","name":"Biostatistician"},{"id":"14","name":"Administrative Manager"},{"id":"140","name":"Clinical Data Systems Specialist / Manager"},{"id":"141","name":"Architect"},{"id":"142","name":"Landscape Architect"},{"id":"143","name":"Surveyor"},{"id":"144","name":"Aerospace Engineer"},{"id":"145","name":"Biomedical Engineer"},{"id":"146","name":"Chemical / Process Engineer"},{"id":"147","name":"Civil Engineer"},{"id":"148","name":"Transportation Engineer"},{"id":"149","name":"Hardware Engineer"},{"id":"15","name":"Chief Information Officer / Director of Information Technology"},{"id":"150","name":"Electrical Engineer"},{"id":"151","name":"Electronics Engineer"},{"id":"152","name":"RF Engineer"},{"id":"153","name":"Environmental Engineer"},{"id":"154","name":"Water / Wastewater Engineer"},{"id":"155","name":"Health and Safety Engineer"},{"id":"156","name":"Industrial Engineer"},{"id":"157","name":"Ergonomist"},{"id":"158","name":"Marine Engineer / Architect"},{"id":"159","name":"Materials Engineer"},{"id":"16","name":"Financial Manager"},{"id":"160","name":"Mechanical Engineer"},{"id":"161","name":"Mining Engineer"},{"id":"162","name":"Nuclear Engineer"},{"id":"163","name":"Reservoir / Petroleum Engineer"},{"id":"164","name":"Validation Engineer"},{"id":"165","name":"Energy Engineer"},{"id":"166","name":"Manufacturing Engineer"},{"id":"167","name":"Optical / Laser Engineer"},{"id":"168","name":"Solar Engineer"},{"id":"169","name":"Energy Efficiency Specialist"},{"id":"17","name":"Treasurer / Controller"},{"id":"170","name":"Civil / Architectural Designer / Drafter"},{"id":"171","name":"Electrical / Electronic Designer"},{"id":"172","name":"Mechanical / Electrical Drafter"},{"id":"173","name":"CAD Designer / Drafter"},{"id":"174","name":"Civil Engineering Technician"},{"id":"175","name":"Electrical and Electronics Technician"},{"id":"176","name":"Test Technician ...
# {'id': '1', 'name': 'na'}

# %%
occupations = pd.DataFrame.from_dict(client.taxonomy().getOccupation())
# Out:
# b'{"data":[{"id":"1","name":"na"},{"id":"10","name":"Business Development / Sales Manager"},{"id":"100","name":"Financial Quantitative Analyst"},{"id":"101","name":"Risk Manager / Analyst"},{"id":"102","name":"Investment Underwriter"},{"id":"103","name":"Fraud Examiner / Analyst"},{"id":"104","name":"Computer Scientist"},{"id":"105","name":"Data Scientist"},{"id":"106","name":"Systems Analyst"},{"id":"107","name":"Cyber / Information Security Engineer / Analyst"},{"id":"108","name":"Software Developer / Engineer"},{"id":"109","name":"Computer Programmer"},{"id":"11","name":"Communications / Public Relations Manager"},{"id":"110","name":"Mobile Applications Developer"},{"id":"111","name":"Computer Systems Engineer / Architect"},{"id":"112","name":"Web Designer"},{"id":"113","name":"Web Developer"},{"id":"114","name":"UI / UX Designer / Developer"},{"id":"115","name":"Database Administrator"},{"id":"116","name":"Network / Systems Administrator"},{"id":"117","name":"Telecommunications Engineering Specialist"},{"id":"118","name":"Computer Support Specialist"},{"id":"119","name":"Network / Systems Support Specialist"},{"id":"12","name":"Fundraising Manager"},{"id":"120","name":"Technology Consultant"},{"id":"121","name":"Software QA Engineer / Tester"},{"id":"122","name":"Network Engineer / Architect"},{"id":"123","name":"Webmaster / Administrator"},{"id":"124","name":"Geographer / GIS Specialist"},{"id":"125","name":"Database Architect"},{"id":"126","name":"Data Warehousing Specialist"},{"id":"127","name":"Project Manager"},{"id":"128","name":"Search Engine Optimization Specialist"},{"id":"129","name":"Video Game Designer"},{"id":"13","name":"Facilities Manager"},{"id":"130","name":"Document Control / Management Specialist"},{"id":"131","name":"Data / Data Mining Analyst"},{"id":"132","name":"Business Intelligence Analyst"},{"id":"133","name":"Business Intelligence Architect / Developer"},{"id":"134","name":"IT Project Manager"},{"id":"135","name":"Actuary"},{"id":"136","name":"Mathematician"},{"id":"137","name":"Operations Analyst"},{"id":"138","name":"Statistician"},{"id":"139","name":"Biostatistician"},{"id":"14","name":"Administrative Manager"},{"id":"140","name":"Clinical Data Systems Specialist / Manager"},{"id":"141","name":"Architect"},{"id":"142","name":"Landscape Architect"},{"id":"143","name":"Surveyor"},{"id":"144","name":"Aerospace Engineer"},{"id":"145","name":"Biomedical Engineer"},{"id":"146","name":"Chemical / Process Engineer"},{"id":"147","name":"Civil Engineer"},{"id":"148","name":"Transportation Engineer"},{"id":"149","name":"Hardware Engineer"},{"id":"15","name":"Chief Information Officer / Director of Information Technology"},{"id":"150","name":"Electrical Engineer"},{"id":"151","name":"Electronics Engineer"},{"id":"152","name":"RF Engineer"},{"id":"153","name":"Environmental Engineer"},{"id":"154","name":"Water / Wastewater Engineer"},{"id":"155","name":"Health and Safety Engineer"},{"id":"156","name":"Industrial Engineer"},{"id":"157","name":"Ergonomist"},{"id":"158","name":"Marine Engineer / Architect"},{"id":"159","name":"Materials Engineer"},{"id":"16","name":"Financial Manager"},{"id":"160","name":"Mechanical Engineer"},{"id":"161","name":"Mining Engineer"},{"id":"162","name":"Nuclear Engineer"},{"id":"163","name":"Reservoir / Petroleum Engineer"},{"id":"164","name":"Validation Engineer"},{"id":"165","name":"Energy Engineer"},{"id":"166","name":"Manufacturing Engineer"},{"id":"167","name":"Optical / Laser Engineer"},{"id":"168","name":"Solar Engineer"},{"id":"169","name":"Energy Efficiency Specialist"},{"id":"17","name":"Treasurer / Controller"},{"id":"170","name":"Civil / Architectural Designer / Drafter"},{"id":"171","name":"Electrical / Electronic Designer"},{"id":"172","name":"Mechanical / Electrical Drafter"},{"id":"173","name":"CAD Designer / Drafter"},{"id":"174","name":"Civil Engineering Technician"},{"id":"175","name":"Electrical and Electronics Technician"},{"id":"176","name":"Test Technician ...

# %%
occupations.head()
# Out:
#     id                                  name
# 0    1                                    na
# 1   10  Business Development / Sales Manager
# 2  100        Financial Quantitative Analyst
# 3  101                Risk Manager / Analyst
# 4  102                Investment Underwriter

# %%
occupations[occupations["name"].str.contains("Data")]
# Out:
#       id                                        name
# 7    105                              Data Scientist
# 18   115                      Database Administrator
# 29   125                          Database Architect
# 30   126                 Data Warehousing Specialist
# 36   131                  Data / Data Mining Analyst
# 46   140  Clinical Data Systems Specialist / Manager
# 457  511                            Data Entry Clerk
# 619  659                               Data Engineer

# %% [markdown]
# Check now the global database

# %%
r = client.globalDataset().getOccupationInsight(
    occupation="Data Scientist",
    area="Milan (ITA)"
)
# Out:
# b'{"area":"Milan (ITA)","occupation":"Data Scientist","date":"2022-07-30T17:38:32.035","area_classification":"market_name","occupation_classification":"occupation_name","salary":{"min":0,"max":0,"median":0,"unique_postings":0},"current_year_active_postings":{"results":[{"month":"2021-06","unique_postings":0},{"month":"2021-07","unique_postings":0},{"month":"2021-08","unique_postings":0},{"month":"2021-09","unique_postings":0},{"month":"2021-10","unique_postings":0},{"month":"2021-11","unique_postings":0},{"month":"2021-12","unique_postings":0},{"month":"2022-01","unique_postings":0},{"month":"2022-02","unique_postings":0},{"month":"2022-03","unique_postings":0},{"month":"2022-04","unique_postings":0},{"month":"2022-05","unique_postings":0},{"month":"2022-06","unique_postings":0}],"total_unique_postings":0},"previous_year_active_postings":{"results":[{"month":"2020-06","unique_postings":0},{"month":"2020-07","unique_postings":0},{"month":"2020-08","unique_postings":0},{"month":"2020-09","unique_postings":0},{"month":"2020-10","unique_postings":0},{"month":"2020-11","unique_postings":0},{"month":"2020-12","unique_postings":0},{"month":"2021-01","unique_postings":0},{"month":"2021-02","unique_postings":0},{"month":"2021-03","unique_postings":0},{"month":"2021-04","unique_postings":0},{"month":"2021-05","unique_postings":0},{"month":"2021-06","unique_postings":0}],"total_unique_postings":0},"top_10_specialized_skills":{"results":[],"limit":10,"rank_by":"unique_postings","analyzed_unique_postings":0},"top_10_common_skills":{"results":[],"limit":10,"rank_by":"unique_postings","analyzed_unique_postings":0},"top_10_employers":{"results":[],"limit":10,"rank_by":"unique_postings","analyzed_unique_postings":0},"top_10_job_titles":{"results":[],"limit":10,"rank_by":"unique_postings","analyzed_unique_postings":0}}'
